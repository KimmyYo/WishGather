# %% [markdown]
# ### 1. Configs

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/u9248731

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# Setup complete ✅ (36 CPUs, 754.4 GB RAM, 0.0/100.0 GB disk)

# %%
# !mkdir {HOME}/world
# %cd {HOME}/world
# Out:
# /home/u9248731/world
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %ls ../datasets/MIS326-12/data.yaml
# Out:
# ../datasets/MIS326-12/data.yaml

# %%
from ultralytics import YOLOWorld

# load model
model = YOLOWorld('yolov8s-worldv2.pt')

# train model 
results = model.train(data='../datasets/MIS326-12/data.yaml', epochs=80, imgsz=800)
# Out:
# ...
# 100%|██████████| 24.7M/24.7M [00:00<00:00, 26.7MB/s]
# New https://pypi.org/project/ultralytics/8.3.21 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# ...

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/world/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/world/runs/detect/train/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/world/runs/detect/train/val_batch2_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/home/u9248731/world/runs/detect/train/weights/best.pt data=/home/u9248731/datasets/MIS326-12/data.yaml
# Out:
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# YOLOv8s-worldv2 summary (fused): 195 layers, 12,749,288 parameters, 0 gradients, 40.8 GFLOPs
# val: Scanning /home/u9248731/datasets/MIS326-12/valid/labels.cache... 245 images
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 1397. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# ...

# %%
# !yolo task=detect mode=predict model=/home/u9248731/world/runs/detect/train/weights/best.pt conf=0.25 source=/home/u9248731/datasets/MIS326-12/test/images save=True
# Out:
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# YOLOv8s-worldv2 summary (fused): 195 layers, 12,749,288 parameters, 0 gradients, 40.8 GFLOPs
#
# image 1/90 /home/u9248731/datasets/MIS326-12/test/images/-1_jpg.rf.b94d346e32b78c586756ec588419e444.jpg: 800x800 8 wongs, 7.9ms
# image 2/90 /home/u9248731/datasets/MIS326-12/test/images/-3_webp.rf.b530f11ca1e8193fb1979328b755f334.jpg: 800x800 1 snow, 8.1ms
# image 3/90 /home/u9248731/datasets/MIS326-12/test/images/-_webp.rf.20571fab572c66a877e38989e111b5f8.jpg: 800x800 1 cookie, 7.8ms
# image 4/90 /home/u9248731/datasets/MIS326-12/test/images/10_jpg.rf.a10032eb0bf1c47012c83f649d380f20.jpg: 800x800 1 pineapple, 5 yuzis, 9.0ms
# image 5/90 /home/u9248731/datasets/MIS326-12/test/images/10_jpg.rf.ab2a4c156c2524153d8fad61049673af.jpg: 800x800 1 canchips, 7.7ms
# ...
